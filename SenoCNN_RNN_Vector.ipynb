# %% [markdown]
# ### Edgar Moises Hernandez-Gonzalez
# #### 13/05/20-17/05/20
# #### Regresion con MLP para predecir la funcion seno

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Sequential
from keras.layers import Conv1D, MaxPool1D, Flatten, LSTM, GRU, Dense
# Out:
# Using TensorFlow backend.

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the sequence
		if out_end_ix > len(sequence):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
#para predecir seno
datos = [-0.0000, -0.0634, -0.1266, -0.1893, -0.2511, -0.3120, -0.3717,
         -0.4298, -0.4862, -0.5406, -0.5929, -0.6428, -0.6901, -0.7346,
         -0.7761, -0.8146, -0.8497, -0.8815, -0.9096, -0.9341, -0.9549,
         -0.9718, -0.9848, -0.9938, -0.9989, -0.9999, -0.9969, -0.9898, 
         -0.9788, -0.9638, -0.9450, -0.9224, -0.8960, -0.8660, -0.8326, 
         -0.7958, -0.7557, -0.7127, -0.6668, -0.6182, -0.5671, -0.5137, 
         -0.4582, -0.4009, -0.3420, -0.2817, -0.2203, -0.1580, -0.0951,
         -0.0317, 0.0317, 0.0951, 0.1580, 0.2203, 0.2817, 0.3420, 0.4009,
         0.4582, 0.5137, 0.5671, 0.6182, 0.6668, 0.7127, 0.7557, 0.7958,
         0.8326, 0.8660, 0.8960, 0.9224, 0.9450, 0.9638, 0.9788, 0.9898,
         0.9969, 0.9999, 0.9989, 0.9938, 0.9848, 0.9718, 0.9549, 0.9341,
         0.9096, 0.8815, 0.8497, 0.8146, 0.7761, 0.7346, 0.6901, 0.6428,
         0.5929, 0.5406, 0.4862, 0.4298, 0.3717, 0.3120, 0.2511, 0.1893,
         0.1266, 0.0634, 0.0000]

# %%
len(datos)
# Out:
# 100

# %%
len_samples = 7
len_vector = 2
x, y = split_sequence(datos, len_samples, len_vector)

# %%
print(x.shape)
print(y.shape)
# Out:
# (92, 7)
# (92, 2)

# %%
#convertir de 2D a 3D
x = x.reshape((x.shape[0], x.shape[1], 1))

print(x.shape)
# Out:
# (92, 7, 1)

# %%
# mse = 0.0482
def model_cnn_1d_vector():
  model = Sequential()
  model.add(Conv1D(8, 3, activation='relu', input_shape=x.shape[1:]))
  model.add(MaxPool1D(2))
  model.add(Flatten())
  model.add(Dense(64, activation='relu'))
  model.add(Dense(len_vector))
  model.compile(optimizer='adam', loss='mse')
  return model

# %%
# mse = 0.0402
def model_lstm_vector():
  model = Sequential()
  model.add(LSTM(64, activation='tanh', input_shape=x.shape[1:]))
  model.add(Dense(len_vector))
  model.compile(optimizer='adam', loss='mse')
  return model

# %%
# mse = 0.0239
def model_gru_vector():
  model = Sequential()
  model.add(GRU(64, activation='tanh', input_shape=x.shape[1:]))
  model.add(Dense(len_vector))
  model.compile(optimizer='adam', loss='mse')
  return model

# %%
#model = model_cnn_1d_vector()
#model = model_lstm_vector()
model = model_gru_vector()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 64)                12672
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 12,802
# Trainable params: 12,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x, y, epochs=20, batch_size=32, verbose=2)
# Out:
# Epoch 1/20
#  - 0s - loss: 0.5847
# Epoch 2/20
#  - 0s - loss: 0.5078
# Epoch 3/20
#  - 0s - loss: 0.4325
# Epoch 4/20
#  - 0s - loss: 0.3666
# Epoch 5/20
#  - 0s - loss: 0.3008
# Epoch 6/20
#  - 0s - loss: 0.2375
# Epoch 7/20
#  - 0s - loss: 0.1759
# Epoch 8/20
#  - 0s - loss: 0.1254
# Epoch 9/20
#  - 0s - loss: 0.0771
# Epoch 10/20
#  - 0s - loss: 0.0452
# Epoch 11/20
#  - 0s - loss: 0.0320
# Epoch 12/20
#  - 0s - loss: 0.0361
# Epoch 13/20
#  - 0s - loss: 0.0439
# Epoch 14/20
#  - 0s - loss: 0.0436
# Epoch 15/20
#  - 0s - loss: 0.0371
# Epoch 16/20
#  - 0s - loss: 0.0309
# Epoch 17/20
#  - 0s - loss: 0.0287
# Epoch 18/20
#  - 0s - loss: 0.0287
# Epoch 19/20
#  - 0s - loss: 0.0290
# Epoch 20/20
#  - 0s - loss: 0.0290

# %%
test_loss = model.evaluate(x, y, verbose=2)
print('Test loss:', test_loss)
# Out:
# Test loss: 0.028611568248142368

# %%
plt.plot(history.history['loss'])
plt.grid()
plt.xlabel('Epocas')
plt.ylabel('MSE')
plt.legend(['train', 'test'])
plt.show()

# %%
predicciones = model.predict(x)

# %%
df_y_test = pd.DataFrame(y)
df_pred = pd.DataFrame(predicciones)
comparar = pd.concat([df_y_test, df_pred], axis=1)
comparar
# Out:
#          0       1         0         1
# 0  -0.4298 -0.4862 -0.153838 -0.184086
# 1  -0.4862 -0.5406 -0.211501 -0.242880
# 2  -0.5406 -0.5929 -0.268390 -0.300749
# 3  -0.5929 -0.6428 -0.324215 -0.357398
# 4  -0.6428 -0.6901 -0.378701 -0.412558
# ..     ...     ...       ...       ...
# 87  0.3120  0.2511  0.499390  0.491585
# 88  0.2511  0.1893  0.452947  0.442865
# 89  0.1893  0.1266  0.404380  0.392056
# 90  0.1266  0.0634  0.353864  0.339353
# 91  0.0634  0.0000  0.301575  0.284932
#
# [92 rows x 4 columns]

# %%
plt.plot(y)
plt.plot(predicciones)
plt.grid()
plt.legend(['y_test_1', 'y_test_2', 'predicciones_1', 'predicciones_2'])
plt.show()

# %%
num_test = 1
print("Etiqueta verdadera", y[num_test])
print("Etiqueta predicha", model.predict(x[num_test].reshape(1,7,1)))
# Out:
# Etiqueta verdadera [-0.4862 -0.5406]
# Etiqueta predicha [[-0.21150135 -0.24288   ]]
